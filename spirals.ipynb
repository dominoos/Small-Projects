# %% [markdown]
# <a href="https://colab.research.google.com/github/dominoos/Small-Projects/blob/main/spirals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# run the code to get coordinates, and then ctrl c ctrl v into desmos

# %%
import math
math.sin(math.pi/2)
# Out:
# 1.0

# %%
h=1000
w=1000

centerx= w/2
centery=h/2
x=w/2
y=h/2
theta= 0
a=-3 #for 3d effect try -3 and
b=0.8 # try 0.8

c=0
for i in range(500):
  x= centerx+ a*theta*math.cos(theta)
  y= centery+ b*theta*math.sin(theta)
  print((x, y))
  if c==1:
    theta+= math.pi/5
    c+=1
  elif c==0:
    theta+=math.pi/6
    c+=1
  else:
    theta+=math.pi/7
    c=0
# Out:
# (500.0, 500.0)
# (498.63965047682433, 500.2094395102393)
# (498.594419065184, 500.8418630582121)
# (500.14365851908394, 501.27999986232743)
# (503.3501538035346, 501.44568996106074)
# (507.6410710208223, 500.83509498919824)
# (509.5871070947041, 499.84683282968683)
# (509.3264344498653, 498.3583132055472)
# (504.5889725814742, 496.7393936755574)
# (498.70861610888613, 496.17374661492306)
# (490.80322647481864, 496.5160263907289)
# (483.09651267971356, 498.46047067428407)
# (480.92880541354197, 500.6115720838178)
# (483.37371182660814, 503.3237157134012)
# (493.3195664468411, 505.7753156413223)
# (503.57861567634274, 506.3313503151692)
# (515.9498294175901, 505.333454261905)
# (526.4766818370749, 501.94855997167724)
# (528.3498575848097, 498.62806916348916)
# (523.1775764331101, 494.7610450244392)
# (507.65026243635424, 491.64035554089537)
# (493.01103990698704, 491.2318741099914)
# (476.4560790710344, 493.02715380483784)
# (463.7392924642167, 497.9446796486591)
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...) \n ![image.png](data:image/png;base64,...)

# %%
h=0
w=000

centerx= w/2
centery=h/2
x=w/2
y=h/2
theta= 0
a=-3 #for 3d effect try -3 and
b=0.8 # try 0.8

c=0
for i in range(500):
  x= centerx+ a*theta*math.cos(theta)
  y= centery+ b*theta*math.sin(theta)
  print((x, y))
  if theta<math.pi:
    theta+= math.pi/10
    c+=1
  elif theta<2*math.pi:
    theta+=math.pi/12
    c+=1
  else:
    theta+=math.pi/14
    c=0
# Out:
# (0.0, 0.0)
# (-0.8963496494224668, 0.07766444154901866)
# (-1.524961107694578, 0.2954530928784731)
# (-1.661923647441411, 0.6099844430778312)
# (-1.16496662323528, 0.9561062927172979)
# (-2.8855060405826847e-16, 1.2566370614359172)
# (1.7474499348529193, 1.4341594390759471)
# (3.8778218440299583, 1.4232970338482729)
# (6.099844430778311, 1.1818123715138926)
# (8.0671468448022, 0.6989799739411682)
# (9.42477796076938, 3.0778731099548636e-16)
# (9.862272809292762, -0.7046901426094441)
# (9.522446662229644, -1.4660765716752373)
# (8.330405509046935, -2.221441469079184)
# (6.283185307179583, -2.9020789827747495)
# (3.4556920454886177, -3.4391515437533733)
# (2.596955436524416e-15, -3.7699111843077517)
# (-3.8622440508402143, -3.843757607724358)
# (-7.853981633974471, -3.627598728468437)
# (-11.662567712665696, -3.1100180567108593)
# (-14.963844754932282, -2.3038346126325204)
# (-17.448636508748717, -1.2467594830782547)
# (-18.84955592153875, -1.0160092598884041e-14)
# ...

# %% [markdown]
# for the above![image.png](data:image/png;base64,...)  ![image.png](data:image/png;base64,...)

# %%
h=0
w=000

centerx= w/2
centery=h/2
x=w/2
y=h/2
theta= 0
a=1#for 3d effect try -3 and
b=1 # try 0.8

c=0
for i in range(1000):
  x= centerx+ a*theta*math.cos(theta)
  y= centery+ b*theta*math.sin(theta)
  print((x, y))
  theta+= math.pi/(10+ 2* int(theta/math.pi))
# Out:
# (0.0, 0.0)
# (0.29878321647415557, 0.09708055193627331)
# (0.508320369231526, 0.3693163660980913)
# (0.5539745491471371, 0.762480553847289)
# (0.38832220774509335, 1.1951328658966223)
# (9.618353468608949e-17, 1.5707963267948966)
# (-0.5824833116176398, 1.7926992988449337)
# (-1.2926072813433194, 1.779121292310341)
# (-2.0332814769261036, 1.4772654643923657)
# (-2.6890489482674003, 0.8737249674264601)
# (-3.141592653589793, 3.8473413874435795e-16)
# (-3.2874242697642533, -0.8808626782618051)
# (-3.1741488874098813, -1.8325957145940466)
# (-2.7768018363489784, -2.7768018363489797)
# (-2.094395102393194, -3.627598728468437)
# (-1.1518973484962058, -4.298939429691716)
# (-8.656518121748053e-16, -4.71238898038469)
# (1.2874146836134048, -4.804697009655447)
# (2.6179938779914904, -4.534498410585546)
# (3.887522570888566, -3.8875225708885743)
# (4.987948251644093, -2.87979326579065)
# (5.816212169582905, -1.5584493538478181)
# (6.2831853071795845, -1.270011574860505e-14)
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %%
import math
h=0
w=000

centerx= w/2
centery=h/2
x=w/2
y=h/2
theta= 0
a=-3#for 3d effect try -3 and
b=0.8 # try 0.8

c=0
for i in range(1000):
  x= centerx+ 20*math.sin(a*theta)*math.cos(theta)
  y= centery+ 20*math.cos(b*theta)*math.sin(theta)
  print((x, y))
  theta+= math.pi/(10+ 2* int(theta/math.pi))
# Out:
# Streaming output truncated to the last 5000 lines.
# (2.07525933807164, -17.40046176482628)
# (2.4978230421744274, -17.487860017479775)
# (2.8571531397732572, -17.559381754462898)
# (3.1522136919581794, -17.614958739027127)
# (3.3825537939041337, -17.654547784458245)
# (3.548307466023085, -17.678130821677243)
# (3.6501888137994762, -17.685714927015084)
# (3.6894825016344366, -17.677332310122612)
# (3.668029622940429, -17.653040262030373)
# (3.5882090850690607, -17.61292106344221)
# (3.4529146629770637, -17.557081853410665)
# (3.2655279097038052, -17.48565445859664)
# (3.029887144354976, -17.398795183391062)
# (2.750252769214841, -17.296684561225472)
# (2.4312691965072344, -17.17952706746812)
# (2.0779236920462107, -17.04755079436366)
# (1.6955024672857049, -16.901007088525137)
# (1.2895443729565876, -16.740170151561347)
# (0.8657925663576171, -16.565336604465838)
# (0.43014454032733507, -16.376825016461012)
# (-0.011399085180662271, -16.17497539904776)
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...) (uses a=20, b=20)
# ![image.png](data:image/png;base64,...) (a=5, b=5)
# ![image.png](data:image/png;base64,...) (a=-3, b=0.8 and there is a 20 in front)
